# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_cbs = pd.read_csv('../../data/raw/CBS_Kerncijfers.csv', sep=';')
df_cbs.describe()
# Out:
#                 ID  IndelingswijzigingGemeenteWijkBuurt_4  AantalInwoners_5  \
# count  1536.000000                            1240.000000       1536.000000
# mean    516.425781                               1.487097       3388.964193
# std      92.826234                               0.854081      16845.341600
# min     381.000000                               1.000000          0.000000
# 25%     433.000000                               1.000000         35.000000
# 50%     501.500000                               1.000000       1180.000000
# 75%     597.250000                               1.000000       2222.500000
# max     693.000000                               3.000000     229574.000000
#
#             Mannen_6      Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  \
# count    1536.000000    1536.000000     1536.000000      1536.000000
# mean     1680.876953    1708.064453      626.045573       425.694661
# std      8357.880021    8487.542602     3104.502056      2140.502172
# ...

# %%
df_cbs = df_cbs[df_cbs["k_0Tot15Jaar_8"] != 0]
df_cbs = df_cbs[df_cbs["k_15Tot25Jaar_9"] != 0]
df_cbs = df_cbs[df_cbs["AantalInwoners_5"] != 0]

df_cbs = df_cbs[df_cbs["k_0Tot15Jaar_8"] != '']
df_cbs = df_cbs[df_cbs["k_15Tot25Jaar_9"] != '']
df_cbs = df_cbs[df_cbs["AantalInwoners_5"] != '']

df_cbs = df_cbs[df_cbs["k_0Tot15Jaar_8"].notna()]
df_cbs = df_cbs[df_cbs["k_15Tot25Jaar_9"].notna()]
df_cbs = df_cbs[df_cbs["AantalInwoners_5"].notna()]
df_cbs.describe()
# Out:
#                 ID  IndelingswijzigingGemeenteWijkBuurt_4  AantalInwoners_5  \
# count  1141.000000                             914.000000       1141.000000
# mean    507.148992                               1.489059       4559.858896
# std      90.166166                               0.858174      19410.094144
# min     381.000000                               1.000000         20.000000
# 25%     427.000000                               1.000000       1000.000000
# 50%     487.000000                               1.000000       1610.000000
# 75%     590.000000                               1.000000       2825.000000
# max     691.000000                               3.000000     229574.000000
#
#             Mannen_6      Vrouwen_7  k_0Tot15Jaar_8  k_15Tot25Jaar_9  \
# count    1141.000000    1141.000000     1141.000000      1141.000000
# mean     2261.531113    2298.244522      842.695881       572.661700
# std      9630.459372    9779.743414     3576.969496      2466.822337
# ...

# %%
df_cbs.to_csv('../../data/processed/CBS_Kerncijfers_cleaned.csv', sep=';', index=False)

# %%
df_groei = pd.read_csv('../../data/processed/df_v10_ratio_temp.csv')

# %%
wijk_mapping = {
    "WK003401": "Haven",
    "WK003402": "Stad",
    "WK003403": "Buiten",
    "WK003404": "Poort",
    "WK003405": "Hout",
}

df_groei["Stadsdeel"] = df_groei["Wijk"].map(wijk_mapping)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for wijk in df_groei["Stadsdeel"].unique():
    plt.figure()
    
    subset1 = df_groei[df_groei["Stadsdeel"] == wijk]
    
    ax = sns.lineplot(
        data=subset1,
        x="Jaar",
        y="k_0Tot15Jaar_8",
        marker="o"
    )
    
    ax.grid(True)
    plt.title(f"Populatie per jaar (0-15) - {wijk}")
    plt.xlabel("Jaar")
    plt.ylabel("Aantal inwoners")
    plt.show()

# %%
from re import S


subset2 = df_groei

subset2['Peildatum'] = pd.to_datetime(subset2['Peildatum'])

subset2 = subset2[subset2['Jaar'].isin([2018, 2021])]

subset2 = subset2.pivot(index='Stadsdeel', columns='Jaar', values='k_0Tot15Jaar_8')

subset2["groei"] = subset2[2021] - subset2[2018]

subset2["percentage_groei"] = (subset2["groei"] / subset2[2018]) * 100

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=subset2.reset_index(),
    x='Stadsdeel',
    y='percentage_groei',
)

plt.title('percentage groei leeftijdsgroep 0-15 jaar per wijk (2018-2021)')

ax.axhline(0, color='black')
ax.set_ylim(subset2['percentage_groei'].min(), subset2['percentage_groei'].max())
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=subset2.reset_index(),
    x='Stadsdeel',
    y='groei',
)

plt.title('groei leeftijdsgroep 0-15 jaar per wijk (2018-2021)')

ax.axhline(0, color='black')
ax.set_ylim(subset2['groei'].min(), subset2['groei'].max())
plt.show()

# %%
subset3 = df_groei

subset3['Peildatum'] = pd.to_datetime(subset3['Peildatum'])

subset3 = subset3[subset3['Jaar'].isin([2018, 2021])]

subset3 = subset3.pivot(index='Stadsdeel', columns='Jaar', values='k_15Tot25Jaar_9')

subset3["groei"] = subset3[2021] - subset3[2018]

subset3["percentage_groei"] = (subset3["groei"] / subset3[2018]) * 100

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=subset3.reset_index(),
    x='Stadsdeel',
    y='percentage_groei',
)

plt.title('percentage groei leeftijdsgroep 15-25 jaar per wijk (2018-2021)')

ax.axhline(0, color='black')
ax.set_ylim(subset3['percentage_groei'].min(), subset3['percentage_groei'].max())
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=subset3.reset_index(),
    x='Stadsdeel',
    y='groei',
)

plt.title('groei leeftijdsgroep 15-25 jaar per wijk (2018-2021)')

ax.axhline(0, color='black')
ax.set_ylim(subset3['groei'].min(), subset3['groei'].max())
plt.show()

# %%
subset4 = df_groei

subset4['Peildatum'] = pd.to_datetime(subset4['Peildatum'])

subset4 = subset4[subset4['Jaar'].isin([2018, 2021])]

subset4 = subset4.pivot(index='Stadsdeel', columns='Jaar', values='AantalInwoners_5')

subset4["groei"] = subset4[2021] - subset4[2018]

subset4["percentage_groei"] = (subset4["groei"] / subset4[2018]) * 100

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=subset4.reset_index(),
    x='Stadsdeel',
    y='percentage_groei',
)

plt.title('percentage groei totaal aantal inwoners per wijk (2018-2021)')

ax.axhline(0, color='black')
ax.set_ylim(subset4['percentage_groei'].min(), subset4['percentage_groei'].max())
plt.show()

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=subset4.reset_index(),
    x='Stadsdeel',
    y='groei',
)

plt.title('groei totaal aantal inwoners per wijk (2018-2021)')

ax.axhline(0, color='black')
ax.set_ylim(subset4['groei'].min(), subset4['groei'].max())
plt.show()

# %%
df_nieuwbouw = pd.read_csv('../../data/raw/Nieuwbouw - Postcodes van Gemeente Almere.csv', sep=';')
df_nieuwbouw.describe()
# Out:
#        Nieuwbouw|2018  Nieuwbouw|2019  Nieuwbouw|2020  Nieuwbouw|2021
# count       16.000000       18.000000       12.000000       16.000000
# mean       102.812500       91.833333      111.250000       90.500000
# std        140.723473      108.009940      135.689569      107.443008
# min          1.000000        5.000000        2.000000        1.000000
# 25%          7.500000       36.250000        7.500000       16.500000
# 50%         44.000000       54.000000       58.000000       61.500000
# 75%        155.750000      115.500000      152.000000      113.250000
# max        547.000000      442.000000      451.000000      387.000000

# %%
df_nieuwbouw = df_nieuwbouw.dropna(
    subset=[
        "Nieuwbouw|2018",
        "Nieuwbouw|2019",
        "Nieuwbouw|2020",
        "Nieuwbouw|2021"
    ],
    how="all"
)
df_nieuwbouw.describe()
# Out:
#        Nieuwbouw|2018  Nieuwbouw|2019  Nieuwbouw|2020  Nieuwbouw|2021
# count       16.000000       18.000000       12.000000       16.000000
# mean       102.812500       91.833333      111.250000       90.500000
# std        140.723473      108.009940      135.689569      107.443008
# min          1.000000        5.000000        2.000000        1.000000
# 25%          7.500000       36.250000        7.500000       16.500000
# 50%         44.000000       54.000000       58.000000       61.500000
# 75%        155.750000      115.500000      152.000000      113.250000
# max        547.000000      442.000000      451.000000      387.000000

# %%
df_nieuwbouw.to_csv('../../data/processed/Nieuwbouw_cleaned.csv', sep=';', index=False)

# %%
df_nieuwbouw_2 = pd.read_csv('../../data/processed/Nieuwbouw_cleaned.csv', sep=';')

# %%
df_nieuwbouw_2["Postcodes"] = df_nieuwbouw_2["Postcodes"].str.extract(r"(\d+)")
df_nieuwbouw_2.head()
# Out:
#   Postcodes  Nieuwbouw|2018  Nieuwbouw|2019  Nieuwbouw|2020  Nieuwbouw|2021
# 0      1315            40.0             NaN             NaN             NaN
# 1      1318             NaN            40.0             NaN             1.0
# 2      1319           103.0           131.0             9.0             NaN
# 3      1325            48.0             NaN             NaN             NaN
# 4      1328             NaN            44.0             NaN             NaN

# %%
postcode_mapping = {
    # Poort
    "1361": "Poort",
    "1362": "Poort",
    "1363": "Poort",

    # Haven
    "1351": "Haven",
    "1352": "Haven",
    "1353": "Haven",
    "1355": "Haven",
    "1358": "Haven",
    "1359": "Haven",

    # Stad
    "1315": "Stad",
    "1318": "Stad",
    "1319": "Stad",
    "1325": "Stad",
    "1328": "Stad",

    # Buiten
    "1331": "Buiten",
    "1334": "Buiten",
    "1335": "Buiten",
    "1336": "Buiten",
    "1339": "Buiten",

    # Hout
    "1341": "Hout",
    "1343": "Hout",
    "1349": "Hout",
}

df_nieuwbouw_2["Stadsdeel"] = df_nieuwbouw_2["Postcodes"].map(postcode_mapping)
df_nieuwbouw_2.head()
# Out:
#   Postcodes  Nieuwbouw|2018  Nieuwbouw|2019  Nieuwbouw|2020  Nieuwbouw|2021  \
# 0      1315            40.0             NaN             NaN             NaN
# 1      1318             NaN            40.0             NaN             1.0
# 2      1319           103.0           131.0             9.0             NaN
# 3      1325            48.0             NaN             NaN             NaN
# 4      1328             NaN            44.0             NaN             NaN
#
#   Stadsdeel
# 0      Stad
# 1      Stad
# 2      Stad
# 3      Stad
# 4      Stad

# %%
df_nieuwbouw_2.to_csv('../../data/processed/Nieuwbouw_cleaned_V2.csv', sep=';', index=False)

# %%
df_nieuwbouw_3 = pd.read_csv('../../data/processed/Nieuwbouw_cleaned_V2.csv', sep=';')

# %%
df_grouped = (
    df_nieuwbouw_3
    .groupby("Stadsdeel", as_index=False)
    .sum(numeric_only=True)
)

print(df_grouped)
# Out:
#   Stadsdeel  Postcodes  Nieuwbouw|2018  Nieuwbouw|2019  Nieuwbouw|2020  \
# 0    Buiten       6675           332.0           207.0           249.0
# 1     Haven       8128            16.0           202.0            48.0
# 2      Hout       4033           336.0           434.0           447.0
# 3     Poort       4086           770.0           595.0           582.0
# 4      Stad       6605           191.0           215.0             9.0
#
#    Nieuwbouw|2021
# 0           339.0
# 1           130.0
# 2           498.0
# 3           480.0
# 4             1.0

# %%
df_grouped.to_csv('../../data/processed/Nieuwbouw_cleaned_V3.csv', sep=';', index=False)

# %%
df_nieuwbouw_4 = pd.read_csv('../../data/processed/Nieuwbouw_cleaned_V3.csv', sep=';')

# %%
df_nieuwbouw_4["totaal_nieuwbouw"] = (
    df_nieuwbouw_4["Nieuwbouw|2018"] +
    df_nieuwbouw_4["Nieuwbouw|2019"] +
    df_nieuwbouw_4["Nieuwbouw|2020"] +
    df_nieuwbouw_4["Nieuwbouw|2021"]
)

# %%
df_plot_1 = subset2.merge(
    df_nieuwbouw_4[["Stadsdeel", "totaal_nieuwbouw"]],
    left_on="Stadsdeel",
    right_on="Stadsdeel",
    how="left"
)

df_plot_2 = subset3.merge(
    df_nieuwbouw_4[["Stadsdeel", "totaal_nieuwbouw"]],
    left_on="Stadsdeel",
    right_on="Stadsdeel",
    how="left"
)

# %%
df_plot_1.to_csv('../../data/processed/df_plot_1.csv', sep=';', index=False)
df_plot_2.to_csv('../../data/processed/df_plot_2.csv', sep=';', index=False)

# %%
fig, ax1 = plt.subplots(figsize=(10,6))

# Groei (balken)
sns.barplot(
    data=df_plot_1,
    x="Stadsdeel",
    y="percentage_groei",
    ax=ax1
)

ax1.axhline(0, color='black')
ax1.set_ylabel("Percentage groei 0-15 jaar")

# Tweede as voor nieuwbouw
ax2 = ax1.twinx()
sns.lineplot(
    data=df_plot_1,
    x="Stadsdeel",
    y="totaal_nieuwbouw",
    marker="o",
    ax=ax2
)

ax2.set_ylabel("Totaal nieuwbouw 2018-2021")

plt.title("Vergelijking: Groei 0-15 jaar vs Nieuwbouw (2018-2021)")
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,6))

# Groei (balken)
sns.barplot(
    data=df_plot_1,
    x="Stadsdeel",
    y="groei",
    ax=ax1
)

ax1.axhline(0, color='black')
ax1.set_ylabel("groei 0-15 jaar")

# Tweede as voor nieuwbouw
ax2 = ax1.twinx()
sns.lineplot(
    data=df_plot_1,
    x="Stadsdeel",
    y="totaal_nieuwbouw",
    marker="o",
    ax=ax2
)

ax2.set_ylabel("Totaal nieuwbouw 2018-2021")

plt.title("Vergelijking: Groei 0-15 jaar vs Nieuwbouw (2018-2021)")
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,6))

# Groei (balken)
sns.barplot(
    data=df_plot_2,
    x="Stadsdeel",
    y="percentage_groei",
    ax=ax1
)

ax1.axhline(0, color='black')
ax1.set_ylabel("Percentage groei 15-25 jaar")

# Tweede as voor nieuwbouw
ax2 = ax1.twinx()
sns.lineplot(
    data=df_plot_2,
    x="Stadsdeel",
    y="totaal_nieuwbouw",
    marker="o",
    ax=ax2
)

ax2.set_ylabel("Totaal nieuwbouw 2018-2021")

plt.title("Vergelijking: Groei 15-25 jaar vs Nieuwbouw (2018-2021)")
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,6))

# Groei (balken)
sns.barplot(
    data=df_plot_2,
    x="Stadsdeel",
    y="groei",
    ax=ax1
)

ax1.axhline(0, color='black')
ax1.set_ylabel("groei 15-25 jaar")

# Tweede as voor nieuwbouw
ax2 = ax1.twinx()
sns.lineplot(
    data=df_plot_2,
    x="Stadsdeel",
    y="totaal_nieuwbouw",
    marker="o",
    ax=ax2
)

ax2.set_ylabel("Totaal nieuwbouw 2018-2021")

plt.title("Vergelijking: Groei 15-25 jaar vs Nieuwbouw (2018-2021)")
plt.show()
